# %%
#line by line
with open("sample.txt","r")as file:
    lines=file.readlines()
    print("Lines in file:")
    print(lines)
# Out:
# Lines in file:
# ['anu\n', 'mca\n', 'kmct']

# %%
#input filenames
file1=input("Enter the source file:")
file2=input("Enter the destination file:")
f1=open(file1,"r")
f2=open(file2,"w")
i=0
for line in f1.readlines():
    i=i+1
    if i %2==0:
        continue
        f2.write(line)
f1.close()
f2.close()
print("odd lines copied sucessfully from",file1,"to",file2)
# Out:
# Enter the source file: source.txt
# Enter the destination file: destination.txt
# odd lines copied sucessfully from source.txt to destination.txt

# %%
import csv
fname=input("Enter csv file name:")
f1=open(fname,"r")
reader=csv.reader(f1)
for row in reader:
    print(row)
f1.close()
# Out:
# Enter csv file name: csv.txt
# ['name', 'age', 'marks']
# ['anu', '21', '80']
# ['saniya', '21', '85']

# %%
import csv
fname=input("Enter the csv file name:")
with open(fname,"r")as f1:
    reader=csv,DictReader(f1)
    print("\nDepartment Details:")
    print("-----------")
    for row in reader:
        print("Deptld:",row['Deptid'],"\tDeptName:",row['DeptName'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 2
#       1 import csv
# ----> 2 fname=input("Enter the csv file name:")
#       3 with open(fname,"r")as f1:
#       4     reader=csv,DictReader(f1)
#
# File ~/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py:1262, in Kernel.raw_input(self, prompt)
#    1260     msg = "raw_input was called, but this frontend does not support input requests."
#    1261     raise StdinNotImplementedError(msg)
# -> 1262 return self._input_request(
#    1263     str(prompt),
#    1264     self._parent_ident["shell"],
#    1265     self.get_parent("shell"),
#    1266     password=False,
#    1267 )
#
# File ~/anaconda3/lib/python3.11/site-packages/ipykernel/kernelbase.py:1305, in Kernel._input_request(self, prompt, ident, parent, password)
#    1302 except KeyboardInterrupt:
# ...

# %%
import csv
data=[
    {"name":"anu","age":21,"marks":85},
    {"name":"saniya","age":22,"marks":90},
    {"name":"meera","age":20,"marks":80}
]
with open("students_dict.csv","w",newline='')as file:
          fieldnames=["name","age","marks"]
          writer=csv.dictWriter(file,fieldnames=fieldnames)
          writer.writeheader()
          writer.writerows(data)
print("Dictionary data written sucessfully!")

#step2
with open("students_dict.csv","r")as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
#   Cell In[10], line 7
#     with open("students_dict.csv","w",newline=")as file:
#                                               ^
# SyntaxError: unterminated string literal (detected at line 7)
